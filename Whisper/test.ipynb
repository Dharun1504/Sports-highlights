# %%
import whisper

# %%
pipe = whisper.load_model('base', device='cuda')
result = pipe.transcribe('F:\Software-Project\Highlights\Sports-highlights\Audios\\1708357021.792142.wav',task='translate')

# %%
result['text']
# Out:
# " Australia vs West Indies, 3-0-20 international Both of them are in the series, and they have lost the game This is dead rubber Powerful batting line, we are able to do better in the 3rd match But in the 2nd match, the target is very strong We did 40 laps in the 3rd match We did 11 laps in the 3rd match We lost in the 2nd match That's why we are in the 2nd match 2nd match, 2nd action, pack teams They are the people who receive it They are the people who receive theidir They beat anyone and won the first game Every game has 3 minutes Out They throw strikers in the 1st match ou theyeri, easy catch Our opponent iscribed to Indies Out They practice比賽 both over & wall Australia. Niklas Puran is a very loose shot. Niklas Puran is a 1-star central. 1-star out. 2-4-7. Inside edge. He's in a beat. He's in a very good position. Silesh Shodd. Hold it. Tama comeback. Xavier Bartlett. Super ball. There's no room in the big. He's played on the players. That's the extra bounce. 3-4-7. Kyle Mayers 
# ...

# %%
len(result['segments'])
# Out:
# 271

# %%
final = []

# %%
for i in (result['segments']):
    new = {}
    new['text'] = i['text']
    new['timestamps'] = [i['start'],i['end']]
    final.append(new)

# %%
final
# Out:
# [{'text': ' Australia vs West Indies, 3-0-20 international',
#   'timestamps': [0.0, 3.44]},
#  {'text': ' Both of them are in the series, and they have lost the game',
#   'timestamps': [3.44, 8.0]},
#  {'text': ' This is dead rubber', 'timestamps': [8.0, 10.0]},
#  {'text': ' Powerful batting line, we are able to do better in the 3rd match',
#   'timestamps': [12.0, 16.4]},
#  {'text': ' But in the 2nd match, the target is very strong',
#   'timestamps': [16.4, 18.400000000000002]},
#  {'text': ' We did 40 laps in the 3rd match',
#   'timestamps': [18.400000000000002, 20.400000000000002]},
#  {'text': ' We did 11 laps in the 3rd match',
#   'timestamps': [20.400000000000002, 22.400000000000002]},
#  {'text': ' We lost in the 2nd match',
#   'timestamps': [22.400000000000002, 23.400000000000002]},
#  {'text': " That's why we are in the 2nd match",
#   'timestamps': [23.400000000000002, 25.400000000000002]},
#  {'text': ' 2nd match, 2nd action, pack teams',
# ...

# %%
from transcription import Transcriptor
# Out:
# WARNING:tensorflow:From f:\gpt\cuda\Lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %%
t = Transcriptor()
# Out:
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.

# %%
ans = t.transcribe(r"f:\Intel-AI\new.wav")
# Out:
# Due to a bug fix in https://github.com/huggingface/transformers/pull/28687 transcription using a multilingual Whisper will default to language detection followed by transcription instead of translation to English.This might be a breaking change for your use case. If you want to instead always translate your audio to English, make sure to pass `language='en'`.
# ...

# %%
import torch
torch.cuda.empty_cache()
